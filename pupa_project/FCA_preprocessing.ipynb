# %%
import anndata
import scanpy
import pandas as pd

# %% [markdown]
# This loads the full body 10x stringently filtered portion of the Fly Cell Atlas. The source is here https://flycellatlas.org/scope. You'll notice the downloads on that page are loom files. In fact, they appear to be standards non-compliant loom files, which caused me much pain in reading them, and I have no idea how I did it. Somehow, I managed to strip a lot of the information and convert it to an h5ad file, which is what we operate on here.

# %%
adata_FCA = anndata.io.read_h5ad("/mnt/z/Caelen/snRNAseq_v2s_fca_biohub_all_wo_blood_10x_converted.h5ad")

# %%
adata_FCA
# Out:
# AnnData object with n_obs × n_vars = 506660 × 16366
#     obs: 'R_annotation', 'R_annotation__ontology_id', 'R_annotation_broad', 'R_annotation_broad__ontology_id', 'age', 'sex', 'tissue', 'batch'
#     var: 'gene_names'

# %% [markdown]
# This is to differentiate these cells from ours when we integrate them later.

# %%
adata_FCA.obs["study"] = "FCA"

# %% [markdown]
# Our samples are only females, so we subset the FCA to only females.

# %%
adata_FCA = adata_FCA[adata_FCA.obs["sex"] == "female"]
adata_FCA
# Out:
# View of AnnData object with n_obs × n_vars = 254580 × 16366
#     obs: 'R_annotation', 'R_annotation__ontology_id', 'R_annotation_broad', 'R_annotation_broad__ontology_id', 'age', 'sex', 'tissue', 'batch'
#     var: 'gene_names'

# %% [markdown]
# Here we remove low confidence annotations and male cell types that appear in females. I'm not sure whats up with those.

# %%
# low confidence
# maybe these should be combined with the high confidence versions?
adata_FCA = adata_FCA[adata_FCA.obs["R_annotation"] != "adult hindgut*"]
adata_FCA = adata_FCA[adata_FCA.obs["R_annotation"] != "adult midgut*"]
adata_FCA = adata_FCA[adata_FCA.obs["R_annotation"] != "posterior midgut*"]
adata_FCA = adata_FCA[adata_FCA.obs["R_annotation"] != "principal cell*"]
adata_FCA = adata_FCA[adata_FCA.obs["R_annotation"] != "hemocyte*"]

# shouldn't be in females?
adata_FCA = adata_FCA[adata_FCA.obs["R_annotation"] != "ejaculatory bulb"]
adata_FCA = adata_FCA[adata_FCA.obs["R_annotation"] != "male germline differentiating cell"]
adata_FCA = adata_FCA[adata_FCA.obs["R_annotation"] != "male accessory gland"]
adata_FCA = adata_FCA[adata_FCA.obs["R_annotation"] != "testis"]

adata_FCA = adata_FCA[adata_FCA.obs["R_annotation_broad"] != "male germline cell"]
adata_FCA = adata_FCA[adata_FCA.obs["R_annotation_broad"] != "male reproductive system"]

adata_FCA
# Out:
# View of AnnData object with n_obs × n_vars = 253970 × 16366
#     obs: 'R_annotation', 'R_annotation__ontology_id', 'R_annotation_broad', 'R_annotation_broad__ontology_id', 'age', 'sex', 'tissue', 'batch', 'DIY_annotation', 'study'
#     var: 'gene_names'

# %% [markdown]
# Here we just look at the cell type distributions.

# %%
counts = adata_FCA.obs["R_annotation_broad"].value_counts()
percentages = adata_FCA.obs["R_annotation_broad"].value_counts(normalize=True) * 100

cell_type_summary = pd.DataFrame({
    'count': counts,
    'percentage': percentages
})

cell_type_summary
# Out:
#                             count  percentage
# R_annotation_broad
# unannotated                 71211   27.990645
# epithelial cell             41815   16.436068
# muscle cell                 32388   12.730632
# female reproductive system  19053    7.489092
# neuron                      17997    7.074014
# sensory neuron              15924    6.259188
# fat cell                    13263    5.213238
# artefact                     9387    3.689713
# glial cell                   7135    2.804528
# female germline cell         5652    2.221611
# tracheolar cell              5306    2.085610
# excretory system             4327    1.700798
# hemocyte                     4290    1.686254
# oenocyte                     2772    1.089580
# somatic precursor cell       2299    0.903659
# pigment cell                  793    0.311702
# gland                         562    0.220903
# cardial cell                  236    0.092764

# %%
counts = adata_FCA.obs["R_annotation"].value_counts()
percentages = adata_FCA.obs["R_annotation"].value_counts(normalize=True) * 100

import pandas as pd
cell_type_summary = pd.DataFrame({
    'count': counts,
    'percentage': percentages
})

cell_type_summary
# Out:
#                                         count  percentage
# R_annotation
# unannotated                             71211   27.990645
# epithelial cell                         26458   10.399748
# muscle cell                             25321    9.952832
# adult fat body                          13131    5.161354
# artefact                                 9230    3.628002
# ...                                       ...         ...
# nociceptive neuron                          8    0.003145
# adult midgut*                               7    0.002751
# antennal trichoid sensillum at4             7    0.002751
# cardial cell                                1    0.000393
# adult lobula astrocyte-like glial cell      1    0.000393
#
# [221 rows x 2 columns]

# %%
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["R_annotation"]
# Out:
# /tmp/ipykernel_151750/1084243048.py:1: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["R_annotation"]

# %% [markdown]
# We could remove unannotated and artefact cells, under the assumption that these may have been misannotated and since we are going to make our final labels by hand. I've tried both ways and I'm undecided.

# %%
#adata_FCA = adata_FCA[adata_FCA.obs["R_annotation"] != "unannotated"]
#adata_FCA = adata_FCA[adata_FCA.obs["R_annotation_broad"] != "unannotated"]
#adata_FCA = adata_FCA[adata_FCA.obs["R_annotation_broad"] != "artefact"]

# %% [markdown]
# Here we create a custom cell type annotation. The FCA broad annotation is too broad, but the main annotation has so many rare/similar cell types that it makes type projection difficult. So we manually collapse many of the similar/rare types into broader categories. My choices here are somewhat arbitrary, and are based on my vague knowledge of biology and on which types appeared to cluster together in earlier attempts.

# %%
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("antimicrobial peptide-producing cell", "artefact")

adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult heart", "cardial cell")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult ostium", "cardial cell")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("cardiomyocyte, working adult heart muscle (non-ostia)", "cardial cell")

adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult enterocyte", "enterocyte")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult midgut enterocyte", "enterocyte")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("enterocyte-like", "enterocyte")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("enterocyte of anterior adult midgut epithelium", "enterocyte")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("enterocyte of posterior adult midgut epithelium", "enterocyte")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult differentiating enterocyte", "enterocyte")

adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("enteroendocrine cell", "epithelial cell")

# Could also be epidermal, no distinct cluster.
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("epidermal cell that specialized in antimicrobial response", "epithelial cell")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("epidermal cell of the abdominal posterior compartment", "epithelial cell")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("tendon cell", "epithelial cell") # I guess tendons are epidermal cells? FBbt_00007325

adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("cardia (1)", "cardia")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("cardia (2)", "cardia")

adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("stalk follicle cell", "follicle cell")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("polar follicle cell", "follicle cell")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("stretch follicle cell", "follicle cell")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("dorsal appendage forming follicle cell", "follicle cell")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("follicle stem cell and prefollicle cell", "follicle cell")

adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("eo support cell", "tormogen or eo support cell")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("tormogen cell", "tormogen or eo support cell")

adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("midgut large flat cell", "midgut")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("copper cell", "midgut")

adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult abdominal pericardial cell", "Malpighian tubule")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult Malpighian tubule", "Malpighian tubule")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult Malpighian tubule bar-shaped cell of initial segment", "Malpighian tubule")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult Malpighian tubule principal cell", "Malpighian tubule")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult Malpighian tubule principal cell of initial segment", "Malpighian tubule")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult Malpighian tubule principal cell of lower segment", "Malpighian tubule")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult Malpighian tubule principal cell of lower ureter", "Malpighian tubule")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult Malpighian tubule principal cell subtype", "Malpighian tubule")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult Malpighian tubule stellate cell of main segment", "Malpighian tubule")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult Malpighian tubule Type I cell", "Malpighian tubule")

adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult fat body", "fat cell")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("pericerebral adult fat mass", "fat cell")

adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("16-cell germline cyst in germarium region 2a and 2b", "female germline cell")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("germ cell stage 4 and later", "female germline cell")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("germline cell", "female germline cell")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("germline cell, unknown stage", "female germline cell")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("post-mitotic germ cell early 16-cell cyst", "female germline cell")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("young germ cell", "female germline cell")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("post-mitotic endocycling nurse cell", "female germline cell")

adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("btl-GAL4 positive female cell, cluster 1, likely to be ovary cell", "ovary cell")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("btl-GAL4 positive female cell, cluster 2, likely to be ovary cell", "ovary cell")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("btl-GAL4 positive female cell, cluster 3, likely to be ovary cell", "ovary cell")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("btl-GAL4 positive female cell, likely to be ovary cell, sim+", "ovary cell")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("btl-GAL4 positive female cell, likely to be ovary cell, sim+, H15+", "ovary cell")

adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("choriogenic main body follicle cell and corpus luteum", "follicle cell")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("choriogenic main body follicle cell St. 12", "follicle cell")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("choriogenic main body follicle cell St. 14", "follicle cell")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("central main body follicle cell ca. St. 6-8", "follicle cell")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("follicle cell St. 9+", "follicle cell")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("main body follicle cell ca. until St. 5", "follicle cell")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("posterior terminal follicle cell ca. St. 5-8", "follicle cell")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("prefollicle cell/stalk follicle cell", "follicle cell")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("escort cell", "follicle cell")

adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult antenna glial cell", "glial cell")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult brain cell body glial cell", "glial cell")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult brain perineurial glial cell", "glial cell")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult glial cell", "glial cell")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult lamina epithelial/marginal glial cell", "glial cell")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult lobula astrocyte-like glial cell", "glial cell")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult optic chiasma glial cell", "glial cell")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult reticular neuropil associated glial cell", "glial cell")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("cell body glial cell", "glial cell")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("CNS surface associated glial cell", "glial cell")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("ensheathing glial cell", "glial cell")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("optic-lobe-associated cortex glial cell", "glial cell")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("perineurial glial sheath", "glial cell")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("pigment cell", "glial cell")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("subperineurial glial cell", "glial cell")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("peripheral glial cell", "glial cell")

adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("crystal cell", "hemocyte")

adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("ovarian sheath muscle", "visceral muscle")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult midgut muscle", "visceral muscle")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("visceral muscle of the midgut", "visceral muscle")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("visceral muscle of the crop", "visceral muscle")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult crop circular muscle", "visceral muscle")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult heart ventral longitudinal muscle", "visceral muscle")

adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("indirect flight muscle", "somatic muscle")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("skeletal muscle of head", "somatic muscle")

adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult alary muscle", "alary muscle")

adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult neuron", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult peripheral nervous system", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult peripheral neuron of the heart", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult ventral nervous system", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("alpha/beta Kenyon cell", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("alpha'/beta' Kenyon cell", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("antennal lobe projection neuron", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("centrifugal neuron C2", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("centrifugal neuron C3", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("columnar neuron T1", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("distal medullary amacrine neuron Dm10", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("distal medullary amacrine neuron Dm11", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("distal medullary amacrine neuron Dm12", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("distal medullary amacrine neuron Dm3", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("distal medullary amacrine neuron Dm8", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("distal medullary amacrine neuron Dm9", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("dopaminergic neuron", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("dopaminergic PAM neuron", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("gamma Kenyon cell", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("Kenyon cell", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("lamina intrinsic neuron", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("lamina monopolar neuron L1", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("lamina monopolar neuron L2", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("lamina monopolar neuron L3", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("lamina monopolar neuron L4", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("lamina monopolar neuron L5", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("lamina intrinsic amacrine neuron Lai", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("lamina wide-field 1 neuron", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("lamina wide-field 2 neuron", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("leg muscle motor neuron", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("lobula columnar neuron LC10", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("lobula columnar neuron LC12", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("lobula columnar neuron LC17", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("medullary intrinsic neuron Mi1", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("medullary intrinsic neuron Mi15", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("medullary intrinsic neuron Mi4", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("medullary intrinsic neuron Mi9", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("multidendritic neuron", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("neuron of haltere", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("octopaminergic/tyraminergic neuron", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("Poxn neuron", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("proximal medullary amacrine neuron Pm2", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("proximal medullary amacrine neuron Pm4", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("sacculus/arista neuron", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("T neuron T2", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("T neuron T2a", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("T neuron T3", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("T neuron T4/T5", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("T neuron T4/T5a-b", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("T neuron T4/T5c-d", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("transmedullary neuron Tm1", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("transmedullary neuron Tm2", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("transmedullary neuron Tm20", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("transmedullary neuron Tm29", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("transmedullary neuron Tm3a", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("transmedullary neuron Tm4", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("transmedullary neuron Tm5c", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("transmedullary neuron Tm9", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("transmedullary Y neuron TmY14", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("transmedullary Y neuron TmY4", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("transmedullary Y neuron TmY5a", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("transmedullary Y neuron TmY8", "neuron")

adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult oenocyte", "oenocyte")

adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult olfactory receptor neuron acid-sensing, Ir64a", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult olfactory receptor neuron acid-sensing, Ir75a/b/c, Ir64a", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult olfactory receptor neuron Gr21a/63a", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult olfactory receptor neuron Ir56a+, Orco-", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult olfactory receptor neuron Ir75d", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult olfactory receptor neuron Ir84a, Ir31a, Ir76a, Ir76b, Ir8a, Or35a", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult olfactory receptor neuron Or13a", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult olfactory receptor neuron Or22a, Or42b, Or59b", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult olfactory receptor neuron Or47a, Or56a and likely other ORN types", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult olfactory receptor neuron Or47b", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult olfactory receptor neuron Or65", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult olfactory receptor neuron Or67a and likely other unknown ORN types", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult olfactory receptor neuron Or67d", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult olfactory receptor neuron Or83c and Or82a", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult olfactory receptor neuron Or85a, Or43b", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult olfactory receptor neuron Or88a", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult olfactory receptor neuron Or92a", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult olfactory receptor neuron unknown type, Orco-", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult olfactory receptor neuron unknown type, Orco+", "neuron")

adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("olfactory receptor neuron", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("olfactory receptor neuron, coeloconics", "neuron")

adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("photoreceptor cell R7", "photoreceptor")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("photoreceptor cell R8", "photoreceptor")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("photoreceptor-like", "photoreceptor")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("ocellus retinula cell", "photoreceptor")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("eye photoreceptor cell", "photoreceptor")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("outer photoreceptor cell", "photoreceptor")

adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("antennal trichoid sensillum at4", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("arista and sacculus thermosensory and hygrosensory neuron Ir21a, Ir40a, Gr28b", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("auditory sensory neuron", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("bitter-sensitive labellar taste bristle", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("dorsal rim area", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("gustatory receptor neuron", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("gustatory receptor neuron of the labellum", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("Johnston organ neuron", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("labral sense organ mechanosensory neuron", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("leg taste bristle chemosensory neuron", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("maxillary palp olfactory receptor neuron", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("maxillary palpus", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("mechanosensory neuron", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("mechanosensory neuron of haltere", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("mechanosensory neuron of leg chordotonal organ", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("nociceptive neuron", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("pheromone-sensing neuron", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("scolopidial neuron", "neuron")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("sensory neuron", "neuron")

adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult hindgut", "hindgut")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult pylorus", "hindgut")

adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult salivary gland", "salivary gland")

adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult renal stem cell", "stem cell")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("intestinal stem cell", "stem cell")
adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("enteroblast", "stem cell")
# Out:
# /tmp/ipykernel_151750/3991152599.py:1: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("antimicrobial peptide-producing cell", "artefact")
# /tmp/ipykernel_151750/3991152599.py:3: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult heart", "cardial cell")
# /tmp/ipykernel_151750/3991152599.py:4: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult ostium", "cardial cell")
# /tmp/ipykernel_151750/3991152599.py:5: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("cardiomyocyte, working adult heart muscle (non-ostia)", "cardial cell")
# /tmp/ipykernel_151750/3991152599.py:7: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult enterocyte", "enterocyte")
# /tmp/ipykernel_151750/3991152599.py:8: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult midgut enterocyte", "enterocyte")
# /tmp/ipykernel_151750/3991152599.py:9: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("enterocyte-like", "enterocyte")
# /tmp/ipykernel_151750/3991152599.py:10: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("enterocyte of anterior adult midgut epithelium", "enterocyte")
# /tmp/ipykernel_151750/3991152599.py:11: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("enterocyte of posterior adult midgut epithelium", "enterocyte")
# /tmp/ipykernel_151750/3991152599.py:12: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult differentiating enterocyte", "enterocyte")
# /tmp/ipykernel_151750/3991152599.py:14: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("enteroendocrine cell", "epithelial cell")
# /tmp/ipykernel_151750/3991152599.py:17: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("epidermal cell that specialized in antimicrobial response", "epithelial cell")
# /tmp/ipykernel_151750/3991152599.py:18: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("epidermal cell of the abdominal posterior compartment", "epithelial cell")
# /tmp/ipykernel_151750/3991152599.py:19: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("tendon cell", "epithelial cell") # I guess tendons are epidermal cells? FBbt_00007325
# /tmp/ipykernel_151750/3991152599.py:21: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("cardia (1)", "cardia")
# /tmp/ipykernel_151750/3991152599.py:22: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("cardia (2)", "cardia")
# /tmp/ipykernel_151750/3991152599.py:24: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("stalk follicle cell", "follicle cell")
# /tmp/ipykernel_151750/3991152599.py:25: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("polar follicle cell", "follicle cell")
# /tmp/ipykernel_151750/3991152599.py:26: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("stretch follicle cell", "follicle cell")
# /tmp/ipykernel_151750/3991152599.py:27: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("dorsal appendage forming follicle cell", "follicle cell")
# /tmp/ipykernel_151750/3991152599.py:28: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("follicle stem cell and prefollicle cell", "follicle cell")
# /tmp/ipykernel_151750/3991152599.py:30: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("eo support cell", "tormogen or eo support cell")
# /tmp/ipykernel_151750/3991152599.py:31: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("tormogen cell", "tormogen or eo support cell")
# /tmp/ipykernel_151750/3991152599.py:33: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("midgut large flat cell", "midgut")
# /tmp/ipykernel_151750/3991152599.py:34: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("copper cell", "midgut")
# /tmp/ipykernel_151750/3991152599.py:36: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult abdominal pericardial cell", "Malpighian tubule")
# /tmp/ipykernel_151750/3991152599.py:37: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult Malpighian tubule", "Malpighian tubule")
# /tmp/ipykernel_151750/3991152599.py:38: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult Malpighian tubule bar-shaped cell of initial segment", "Malpighian tubule")
# /tmp/ipykernel_151750/3991152599.py:39: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult Malpighian tubule principal cell", "Malpighian tubule")
# /tmp/ipykernel_151750/3991152599.py:40: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult Malpighian tubule principal cell of initial segment", "Malpighian tubule")
# /tmp/ipykernel_151750/3991152599.py:41: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult Malpighian tubule principal cell of lower segment", "Malpighian tubule")
# /tmp/ipykernel_151750/3991152599.py:42: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult Malpighian tubule principal cell of lower ureter", "Malpighian tubule")
# /tmp/ipykernel_151750/3991152599.py:43: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult Malpighian tubule principal cell subtype", "Malpighian tubule")
# /tmp/ipykernel_151750/3991152599.py:44: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult Malpighian tubule stellate cell of main segment", "Malpighian tubule")
# /tmp/ipykernel_151750/3991152599.py:45: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult Malpighian tubule Type I cell", "Malpighian tubule")
# /tmp/ipykernel_151750/3991152599.py:47: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult fat body", "fat cell")
# /tmp/ipykernel_151750/3991152599.py:48: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("pericerebral adult fat mass", "fat cell")
# /tmp/ipykernel_151750/3991152599.py:50: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("16-cell germline cyst in germarium region 2a and 2b", "female germline cell")
# /tmp/ipykernel_151750/3991152599.py:51: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("germ cell stage 4 and later", "female germline cell")
# /tmp/ipykernel_151750/3991152599.py:52: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("germline cell", "female germline cell")
# /tmp/ipykernel_151750/3991152599.py:53: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("germline cell, unknown stage", "female germline cell")
# /tmp/ipykernel_151750/3991152599.py:54: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("post-mitotic germ cell early 16-cell cyst", "female germline cell")
# /tmp/ipykernel_151750/3991152599.py:55: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("young germ cell", "female germline cell")
# /tmp/ipykernel_151750/3991152599.py:56: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("post-mitotic endocycling nurse cell", "female germline cell")
# /tmp/ipykernel_151750/3991152599.py:58: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("btl-GAL4 positive female cell, cluster 1, likely to be ovary cell", "ovary cell")
# /tmp/ipykernel_151750/3991152599.py:59: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("btl-GAL4 positive female cell, cluster 2, likely to be ovary cell", "ovary cell")
# /tmp/ipykernel_151750/3991152599.py:60: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("btl-GAL4 positive female cell, cluster 3, likely to be ovary cell", "ovary cell")
# /tmp/ipykernel_151750/3991152599.py:61: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("btl-GAL4 positive female cell, likely to be ovary cell, sim+", "ovary cell")
# /tmp/ipykernel_151750/3991152599.py:62: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("btl-GAL4 positive female cell, likely to be ovary cell, sim+, H15+", "ovary cell")
# /tmp/ipykernel_151750/3991152599.py:64: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("choriogenic main body follicle cell and corpus luteum", "follicle cell")
# /tmp/ipykernel_151750/3991152599.py:65: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("choriogenic main body follicle cell St. 12", "follicle cell")
# /tmp/ipykernel_151750/3991152599.py:66: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("choriogenic main body follicle cell St. 14", "follicle cell")
# /tmp/ipykernel_151750/3991152599.py:67: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("central main body follicle cell ca. St. 6-8", "follicle cell")
# /tmp/ipykernel_151750/3991152599.py:68: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("follicle cell St. 9+", "follicle cell")
# /tmp/ipykernel_151750/3991152599.py:69: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("main body follicle cell ca. until St. 5", "follicle cell")
# /tmp/ipykernel_151750/3991152599.py:70: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("posterior terminal follicle cell ca. St. 5-8", "follicle cell")
# /tmp/ipykernel_151750/3991152599.py:71: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("prefollicle cell/stalk follicle cell", "follicle cell")
# /tmp/ipykernel_151750/3991152599.py:72: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("escort cell", "follicle cell")
# /tmp/ipykernel_151750/3991152599.py:74: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult antenna glial cell", "glial cell")
# /tmp/ipykernel_151750/3991152599.py:75: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult brain cell body glial cell", "glial cell")
# /tmp/ipykernel_151750/3991152599.py:76: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult brain perineurial glial cell", "glial cell")
# /tmp/ipykernel_151750/3991152599.py:77: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult glial cell", "glial cell")
# /tmp/ipykernel_151750/3991152599.py:78: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult lamina epithelial/marginal glial cell", "glial cell")
# /tmp/ipykernel_151750/3991152599.py:79: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult lobula astrocyte-like glial cell", "glial cell")
# /tmp/ipykernel_151750/3991152599.py:80: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult optic chiasma glial cell", "glial cell")
# /tmp/ipykernel_151750/3991152599.py:81: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult reticular neuropil associated glial cell", "glial cell")
# /tmp/ipykernel_151750/3991152599.py:82: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("cell body glial cell", "glial cell")
# /tmp/ipykernel_151750/3991152599.py:83: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("CNS surface associated glial cell", "glial cell")
# /tmp/ipykernel_151750/3991152599.py:84: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("ensheathing glial cell", "glial cell")
# /tmp/ipykernel_151750/3991152599.py:85: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("optic-lobe-associated cortex glial cell", "glial cell")
# /tmp/ipykernel_151750/3991152599.py:86: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("perineurial glial sheath", "glial cell")
# /tmp/ipykernel_151750/3991152599.py:87: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("pigment cell", "glial cell")
# /tmp/ipykernel_151750/3991152599.py:88: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("subperineurial glial cell", "glial cell")
# /tmp/ipykernel_151750/3991152599.py:89: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("peripheral glial cell", "glial cell")
# /tmp/ipykernel_151750/3991152599.py:91: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("crystal cell", "hemocyte")
# /tmp/ipykernel_151750/3991152599.py:93: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("ovarian sheath muscle", "visceral muscle")
# /tmp/ipykernel_151750/3991152599.py:95: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("visceral muscle of the midgut", "visceral muscle")
# /tmp/ipykernel_151750/3991152599.py:96: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("visceral muscle of the crop", "visceral muscle")
# /tmp/ipykernel_151750/3991152599.py:98: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult heart ventral longitudinal muscle", "visceral muscle")
# /tmp/ipykernel_151750/3991152599.py:100: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("indirect flight muscle", "somatic muscle")
# /tmp/ipykernel_151750/3991152599.py:101: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("skeletal muscle of head", "somatic muscle")
# /tmp/ipykernel_151750/3991152599.py:103: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult alary muscle", "alary muscle")
# /tmp/ipykernel_151750/3991152599.py:105: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult neuron", "neuron")
# /tmp/ipykernel_151750/3991152599.py:106: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult peripheral nervous system", "neuron")
# /tmp/ipykernel_151750/3991152599.py:107: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult peripheral neuron of the heart", "neuron")
# /tmp/ipykernel_151750/3991152599.py:108: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult ventral nervous system", "neuron")
# /tmp/ipykernel_151750/3991152599.py:109: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("alpha/beta Kenyon cell", "neuron")
# /tmp/ipykernel_151750/3991152599.py:110: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("alpha'/beta' Kenyon cell", "neuron")
# /tmp/ipykernel_151750/3991152599.py:111: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("antennal lobe projection neuron", "neuron")
# /tmp/ipykernel_151750/3991152599.py:112: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("centrifugal neuron C2", "neuron")
# /tmp/ipykernel_151750/3991152599.py:113: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("centrifugal neuron C3", "neuron")
# /tmp/ipykernel_151750/3991152599.py:114: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("columnar neuron T1", "neuron")
# /tmp/ipykernel_151750/3991152599.py:115: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("distal medullary amacrine neuron Dm10", "neuron")
# /tmp/ipykernel_151750/3991152599.py:116: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("distal medullary amacrine neuron Dm11", "neuron")
# /tmp/ipykernel_151750/3991152599.py:117: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("distal medullary amacrine neuron Dm12", "neuron")
# /tmp/ipykernel_151750/3991152599.py:118: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("distal medullary amacrine neuron Dm3", "neuron")
# /tmp/ipykernel_151750/3991152599.py:119: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("distal medullary amacrine neuron Dm8", "neuron")
# /tmp/ipykernel_151750/3991152599.py:120: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("distal medullary amacrine neuron Dm9", "neuron")
# /tmp/ipykernel_151750/3991152599.py:121: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("dopaminergic neuron", "neuron")
# /tmp/ipykernel_151750/3991152599.py:122: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("dopaminergic PAM neuron", "neuron")
# /tmp/ipykernel_151750/3991152599.py:123: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("gamma Kenyon cell", "neuron")
# /tmp/ipykernel_151750/3991152599.py:124: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("Kenyon cell", "neuron")
# /tmp/ipykernel_151750/3991152599.py:126: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("lamina monopolar neuron L1", "neuron")
# /tmp/ipykernel_151750/3991152599.py:127: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("lamina monopolar neuron L2", "neuron")
# /tmp/ipykernel_151750/3991152599.py:128: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("lamina monopolar neuron L3", "neuron")
# /tmp/ipykernel_151750/3991152599.py:129: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("lamina monopolar neuron L4", "neuron")
# /tmp/ipykernel_151750/3991152599.py:130: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("lamina monopolar neuron L5", "neuron")
# /tmp/ipykernel_151750/3991152599.py:131: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("lamina intrinsic amacrine neuron Lai", "neuron")
# /tmp/ipykernel_151750/3991152599.py:132: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("lamina wide-field 1 neuron", "neuron")
# /tmp/ipykernel_151750/3991152599.py:133: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("lamina wide-field 2 neuron", "neuron")
# /tmp/ipykernel_151750/3991152599.py:134: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("leg muscle motor neuron", "neuron")
# /tmp/ipykernel_151750/3991152599.py:135: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("lobula columnar neuron LC10", "neuron")
# /tmp/ipykernel_151750/3991152599.py:136: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
# ...
# /tmp/ipykernel_151750/3991152599.py:184: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult olfactory receptor neuron Or85a, Or43b", "neuron")
# /tmp/ipykernel_151750/3991152599.py:185: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult olfactory receptor neuron Or88a", "neuron")
# /tmp/ipykernel_151750/3991152599.py:186: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult olfactory receptor neuron Or92a", "neuron")
# /tmp/ipykernel_151750/3991152599.py:187: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult olfactory receptor neuron unknown type, Orco-", "neuron")
# /tmp/ipykernel_151750/3991152599.py:188: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult olfactory receptor neuron unknown type, Orco+", "neuron")
# /tmp/ipykernel_151750/3991152599.py:190: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("olfactory receptor neuron", "neuron")
# /tmp/ipykernel_151750/3991152599.py:191: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("olfactory receptor neuron, coeloconics", "neuron")
# /tmp/ipykernel_151750/3991152599.py:193: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("photoreceptor cell R7", "photoreceptor")
# /tmp/ipykernel_151750/3991152599.py:194: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("photoreceptor cell R8", "photoreceptor")
# /tmp/ipykernel_151750/3991152599.py:195: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("photoreceptor-like", "photoreceptor")
# /tmp/ipykernel_151750/3991152599.py:196: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("ocellus retinula cell", "photoreceptor")
# /tmp/ipykernel_151750/3991152599.py:197: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("eye photoreceptor cell", "photoreceptor")
# /tmp/ipykernel_151750/3991152599.py:198: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("outer photoreceptor cell", "photoreceptor")
# /tmp/ipykernel_151750/3991152599.py:200: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("antennal trichoid sensillum at4", "neuron")
# /tmp/ipykernel_151750/3991152599.py:201: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("arista and sacculus thermosensory and hygrosensory neuron Ir21a, Ir40a, Gr28b", "neuron")
# /tmp/ipykernel_151750/3991152599.py:202: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("auditory sensory neuron", "neuron")
# /tmp/ipykernel_151750/3991152599.py:203: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("bitter-sensitive labellar taste bristle", "neuron")
# /tmp/ipykernel_151750/3991152599.py:204: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("dorsal rim area", "neuron")
# /tmp/ipykernel_151750/3991152599.py:205: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("gustatory receptor neuron", "neuron")
# /tmp/ipykernel_151750/3991152599.py:206: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("gustatory receptor neuron of the labellum", "neuron")
# /tmp/ipykernel_151750/3991152599.py:207: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("Johnston organ neuron", "neuron")
# /tmp/ipykernel_151750/3991152599.py:208: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("labral sense organ mechanosensory neuron", "neuron")
# /tmp/ipykernel_151750/3991152599.py:209: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("leg taste bristle chemosensory neuron", "neuron")
# /tmp/ipykernel_151750/3991152599.py:210: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("maxillary palp olfactory receptor neuron", "neuron")
# /tmp/ipykernel_151750/3991152599.py:211: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("maxillary palpus", "neuron")
# /tmp/ipykernel_151750/3991152599.py:212: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("mechanosensory neuron", "neuron")
# /tmp/ipykernel_151750/3991152599.py:213: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("mechanosensory neuron of haltere", "neuron")
# /tmp/ipykernel_151750/3991152599.py:214: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("mechanosensory neuron of leg chordotonal organ", "neuron")
# /tmp/ipykernel_151750/3991152599.py:215: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("nociceptive neuron", "neuron")
# /tmp/ipykernel_151750/3991152599.py:216: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("pheromone-sensing neuron", "neuron")
# /tmp/ipykernel_151750/3991152599.py:217: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("scolopidial neuron", "neuron")
# /tmp/ipykernel_151750/3991152599.py:218: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("sensory neuron", "neuron")
# /tmp/ipykernel_151750/3991152599.py:220: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult hindgut", "hindgut")
# /tmp/ipykernel_151750/3991152599.py:221: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult pylorus", "hindgut")
# /tmp/ipykernel_151750/3991152599.py:223: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult salivary gland", "salivary gland")
# /tmp/ipykernel_151750/3991152599.py:225: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("adult renal stem cell", "stem cell")
# /tmp/ipykernel_151750/3991152599.py:226: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("intestinal stem cell", "stem cell")
# /tmp/ipykernel_151750/3991152599.py:227: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata_FCA.obs["DIY_annotation"] = adata_FCA.obs["DIY_annotation"].replace("enteroblast", "stem cell")

# %% [markdown]
# We examine the cell type distributions again after our changes.

# %%
counts = adata_FCA.obs["R_annotation"].value_counts()
percentages = adata_FCA.obs["R_annotation"].value_counts(normalize=True) * 100

cell_type_summary = pd.DataFrame({
    'count': counts,
    'percentage': percentages
})

cell_type_summary
# Out:
#                                         count  percentage
# R_annotation
# unannotated                             71211   28.039138
# epithelial cell                         26458   10.417766
# muscle cell                             25321    9.970075
# adult fat body                          13131    5.170296
# artefact                                 9230    3.634288
# ...                                       ...         ...
# copper cell                                 9    0.003544
# nociceptive neuron                          8    0.003150
# antennal trichoid sensillum at4             7    0.002756
# cardial cell                                1    0.000394
# adult lobula astrocyte-like glial cell      1    0.000394
#
# [216 rows x 2 columns]

# %%
counts = adata_FCA.obs["R_annotation_broad"].value_counts()
percentages = adata_FCA.obs["R_annotation_broad"].value_counts(normalize=True) * 100

cell_type_summary = pd.DataFrame({
    'count': counts,
    'percentage': percentages
})

cell_type_summary
# Out:
#                             count  percentage
# R_annotation_broad
# unannotated                 71211   28.039138
# epithelial cell             41520   16.348388
# muscle cell                 32388   12.752687
# female reproductive system  19053    7.502067
# neuron                      17997    7.086270
# sensory neuron              15924    6.270032
# fat cell                    13263    5.222270
# artefact                     9387    3.696106
# glial cell                   7135    2.809387
# female germline cell         5652    2.225460
# tracheolar cell              5306    2.089223
# excretory system             4327    1.703745
# hemocyte                     4145    1.632083
# oenocyte                     2772    1.091467
# somatic precursor cell       2299    0.905225
# pigment cell                  793    0.312242
# gland                         562    0.221286
# cardial cell                  236    0.092924

# %%
counts = adata_FCA.obs["DIY_annotation"].value_counts()
percentages = adata_FCA.obs["DIY_annotation"].value_counts(normalize=True) * 100

cell_type_summary = pd.DataFrame({
    'count': counts,
    'percentage': percentages
})

cell_type_summary
# Out:
#                                   count  percentage
# DIY_annotation
# unannotated                       71211   28.039138
# epithelial cell                   27647   10.885931
# neuron                            26934   10.605190
# muscle cell                       25321    9.970075
# follicle cell                     15549    6.122377
# fat cell                          13263    5.222270
# ovary cell                        10450    4.114659
# artefact                           9387    3.696106
# glial cell                         7928    3.121629
# female germline cell               5903    2.324290
# somatic muscle                     5840    2.299484
# adult tracheocyte                  5306    2.089223
# Malpighian tubule                  4405    1.734457
# hemocyte                           4145    1.632083
# photoreceptor                      3460    1.362366
# cone cell                          3016    1.187542
# crop                               2822    1.111155
# oenocyte                           2772    1.091467
# stem cell                          1899    0.747726
# enterocyte                          990    0.389810
# visceral muscle                     964    0.379572
# cardia                              856    0.337048
# female reproductive system          853    0.335866
# oviduct                             569    0.224042
# salivary gland                      562    0.221286
# tormogen or eo support cell         511    0.201205
# hindgut                             291    0.114580
# adult esophagus                     266    0.104737
# alary muscle                        263    0.103556
# cardial cell                        236    0.092924
# adult midgut-hindgut hybrid zone    201    0.079143
# midgut                              150    0.059062

# %% [markdown]
# This ensures there are no cell types with very few cells, about which scANVI complains. It may be better to group these with other similar cell types, but for now we just remove them.

# %%
counts = adata_FCA.obs["R_annotation"].value_counts()

adata_FCA = adata_FCA[adata_FCA.obs["R_annotation"].isin(counts[counts > 3].index)]

# %%
counts = adata_FCA.obs["R_annotation"].value_counts()
percentages = adata_FCA.obs["R_annotation"].value_counts(normalize=True) * 100

cell_type_summary = pd.DataFrame({
    'count': counts,
    'percentage': percentages
})

cell_type_summary
# Out:
#                                        count  percentage
# R_annotation
# unannotated                            71211   28.039359
# epithelial cell                        26458   10.417848
# muscle cell                            25321    9.970154
# adult fat body                         13131    5.170336
# artefact                                9230    3.634316
# ...                                      ...         ...
# adult olfactory receptor neuron Or13a     15    0.005906
# adult heart                               10    0.003938
# copper cell                                9    0.003544
# nociceptive neuron                         8    0.003150
# antennal trichoid sensillum at4            7    0.002756
#
# [214 rows x 2 columns]

# %%
adata_FCA
# Out:
# View of AnnData object with n_obs × n_vars = 253968 × 16366
#     obs: 'R_annotation', 'R_annotation__ontology_id', 'R_annotation_broad', 'R_annotation_broad__ontology_id', 'age', 'sex', 'tissue', 'batch', 'DIY_annotation', 'study'
#     var: 'gene_names'

# %% [markdown]
# We filter some of the very low count cells and genes, just to make sure there's nothing weird going on that scANVI would complain about later.

# %%
scanpy.pp.filter_cells(adata_FCA, min_genes=50)
scanpy.pp.filter_cells(adata_FCA, min_counts=100)

scanpy.pp.filter_genes(adata_FCA, min_cells=10)
scanpy.pp.filter_genes(adata_FCA, min_counts=10)

# %%
adata_FCA
# Out:
# AnnData object with n_obs × n_vars = 253968 × 15017
#     obs: 'R_annotation', 'R_annotation__ontology_id', 'R_annotation_broad', 'R_annotation_broad__ontology_id', 'age', 'sex', 'tissue', 'batch', 'DIY_annotation', 'study', 'n_genes', 'n_counts'
#     var: 'gene_names', 'n_cells', 'n_counts'

# %%
adata_FCA.write_h5ad("/mnt/z/Caelen/snRNAseq_v2/adata_FCA.h5ad")
