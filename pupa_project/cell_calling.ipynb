# %%
import anndata

# %%
cellbender_run = "concat_all_multimapper_em_1st_pass_auto"

genotype="wildtype"

# %%
adata_a0_s1 = anndata.io.read_h5ad("../working_dir/raw_h5ad/" + genotype + "_a0_s1.h5ad")
adata_a0_s2 = anndata.io.read_h5ad("../working_dir/raw_h5ad/" + genotype + "_a0_s2.h5ad")
adata_p1_s1 = anndata.io.read_h5ad("../working_dir/raw_h5ad/" + genotype + "_p1_s1.h5ad")
adata_p1_s2 = anndata.io.read_h5ad("../working_dir/raw_h5ad/" + genotype + "_p1_s2.h5ad")
adata_p2_s1 = anndata.io.read_h5ad("../working_dir/raw_h5ad/" + genotype + "_p2_s1.h5ad")
adata_p2_s2 = anndata.io.read_h5ad("../working_dir/raw_h5ad/" + genotype + "_p2_s2.h5ad")
adata_p3_s1 = anndata.io.read_h5ad("../working_dir/raw_h5ad/" + genotype + "_p3_s1.h5ad")
adata_p3_s2 = anndata.io.read_h5ad("../working_dir/raw_h5ad/" + genotype + "_p3_s2.h5ad")
adata_p4_s1 = anndata.io.read_h5ad("../working_dir/raw_h5ad/" + genotype + "_p4_s1.h5ad")
adata_p4_s2 = anndata.io.read_h5ad("../working_dir/raw_h5ad/" + genotype + "_p4_s2.h5ad")
adata_wp_s1 = anndata.io.read_h5ad("../working_dir/raw_h5ad/" + genotype + "_wp_s1.h5ad")
adata_wp_s2 = anndata.io.read_h5ad("../working_dir/raw_h5ad/" + genotype + "_wp_s2.h5ad")
